# %%
import json
import glob
import os
path = 'F:\\CPmod\\Vs_apartmen\\source\\raw'
jsonpath = glob.glob(path+"\**\*.streamingblock.json", recursive = True)
filepath = jsonpath[0]

with open(filepath,'r') as f: 
      j=json.load(f)

# %%
from pprint import pprint
data=j['Data']['RootChunk']['descriptors']

pprint(data[0]['data'])
# Out:
# {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-18_3_-12_0.streamingsector',
#  'Flags': 'Soft'}

# %%
def split_on_uppercase(s, keep_contiguous=False):
    """

    Args:
        s (str): string
        keep_contiguous (bool): flag to indicate we want to 
                                keep contiguous uppercase chars together

    Returns:

    """

    string_length = len(s)
    is_lower_around = (lambda: s[i-1].islower() or 
                       string_length > (i + 1) and s[i + 1].islower())

    start = 0
    parts = []
    for i in range(1, string_length):
        if s[i].isupper() and (not keep_contiguous or is_lower_around()):
            parts.append(s[start: i])
            start = i
    parts.append(s[start:])

    return parts

# %%
import json
import glob
import os
path = 'F:\\CPmod\\Vs_apartmen\\source\\raw'
jsonpath = glob.glob(path+"\**\*.streamingsector.json", recursive = True)
filepath = jsonpath[0]

with open(filepath,'r') as f: 
      t=json.load(f)

# %%
nodeRefs=t['Data']['RootChunk']['nodeRefs']

# %%
Variant_nodeRefs=[]
Res={}
for i,d in enumerate(data): 
    for v in d['variants']:
        Variant_nodeRefs.append(v['nodeRef'])
        for n in nodeRefs:
            if split_on_uppercase(v['nodeRef'],True)[0]==split_on_uppercase(n,True)[0]:
                Res[str(i)]=d['data']['DepotPath']
            #pprint((i,d['data']['DepotPath']))
pprint(Res)
# Out:
# {'15310': 'base\\worlds\\03_night_city\\_compiled\\default\\interior_-44_40_3_0.streamingsector',
#  '16964': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_2467054678ccf8f6.streamingsector',
#  '17019': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_2be595b225125038.streamingsector',
#  '17090': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_3509076113f76078.streamingsector',
#  '18159': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_acd280b2b73c4d5b.streamingsector',
#  '18607': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_e1ef450702659584.streamingsector'}

# %%
split_on_uppercase(nodeRefs[1],True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 split_on_uppercase(nodeRefs[1],True)
#
# IndexError: list index out of range

# %%
Variant_nodeRefs=[]
for d in data: 
    for v in d['variants']:
        Variant_nodeRefs.append(v['nodeRef'])
        if split_on_uppercase(v['nodeRef'],True)[0]==split_on_uppercase(nodeRefs[0],True)[3]:
            pprint(d['data']['DepotPath'])

# %%
pprint(Variant_nodeRefs)

# %%
split_on_uppercase(Variant_nodeRefs[0],True)[0]

# %%
sectors_of_interest=[]
for i,v in enumerate(Variant_nodeRefs):
    if 'arasaka_hotel' in v:
        sectors_of_interest.append((i,v))
pprint(sectors_of_interest)
# Out:
# [(6232,
#   '$/03_night_city/c_watson/arasaka_waterfront/loc_q004_q005_arasaka_hotel_prefabSAJNFOI/#loc_q004_q005_arasaka_hotel_lighting/floor_01_prefabJHWYSRA/#konpeki_plaza_floor_01_guest_room_002'),
#  (6233,
#   '$/03_night_city/c_watson/arasaka_waterfront/loc_q004_q005_arasaka_hotel_prefabSAJNFOI/#loc_q004_q005_arasaka_hotel_lighting/floor_01_prefabJHWYSRA/#konpeki_plaza_floor_01_guest_room_002'),
#  (6234,
#   '$/03_night_city/c_watson/arasaka_waterfront/loc_q004_q005_arasaka_hotel_prefabSAJNFOI/#loc_q004_q005_arasaka_hotel_lighting/floor_01_prefabJHWYSRA/#floor_01_guest_room'),
#  (6235,
#   '$/03_night_city/c_watson/arasaka_waterfront/loc_q004_q005_arasaka_hotel_prefabSAJNFOI/#loc_q004_q005_arasaka_hotel_lighting/floor_01_prefabJHWYSRA/#floor_01_guest_room'),
#  (6236,
#   '$/03_night_city/c_watson/arasaka_waterfront/loc_q004_q005_arasaka_hotel_prefabSAJNFOI/loc_q004_q005_arasaka_hotel_audio_prefabREQQQMY/#loc_q004_005_arasaka_hotel_audio_music'),
#  (6237,
# ...

# %%
sectors_of_interest=[]
for i,d in enumerate(data):
    for v in d['variants']:
        if 'atlantis' in v['nodeRef']:
            sectors_of_interest.append((i,d['data']))
pprint(sectors_of_interest)
# Out:
# [(4257,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-11_15_1_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4257,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-11_15_1_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4407,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-13_17_0_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4407,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-13_17_0_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4407,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-13_17_0_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4407,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-13_17_0_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4407,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-13_17_0_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4407,
# ...

# %%
sectors_of_interest=[]
for i,d in enumerate(data):
    for v in d['variants']:
        if 'hym' in v['nodeRef']:
            sectors_of_interest.append((i,d['data']))
pprint(sectors_of_interest)
# Out:
# [(18644,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_e6340f4e7a9a4922.streamingsector',
#    'Flags': 'Soft'}),
#  (18644,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_e6340f4e7a9a4922.streamingsector',
#    'Flags': 'Soft'}),
#  (18644,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_e6340f4e7a9a4922.streamingsector',
#    'Flags': 'Soft'}),
#  (18644,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_e6340f4e7a9a4922.streamingsector',
#    'Flags': 'Soft'}),
#  (18644,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\quest_e6340f4e7a9a4922.streamingsector',
#    'Flags': 'Soft'})]

# %%
sectors_of_interest=[]
for i,d in enumerate(data):
    for v in d['variants']:
        if 'arasaka_hotel' in v['nodeRef']:
            sectors_of_interest.append((i,d['data']))
pprint(sectors_of_interest)
# Out:
# [(4695,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-35_27_2_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4695,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-35_27_2_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4695,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-35_27_2_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4695,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-35_27_2_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4695,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-35_27_2_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4695,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-35_27_2_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4696,
#   {'DepotPath': 'base\\worlds\\03_night_city\\_compiled\\default\\exterior_-35_27_1_0.streamingsector',
#    'Flags': 'Soft'}),
#  (4697,
# ...
